# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
Class_churn=df["Churn"].value_counts()

# %%
Class_churn
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.pie(
    Class_churn,
    labels=["NO","Yes"],
    autopct="%1.1f%%",
    colors=['r','g'],
    wedgeprops={
        'linewidth': 2,
        'edgecolor': "black"
    }
)
plt.title("Number of Churn")
plt.tight_layout()

# %%
class_phone_service=df["PhoneService"].value_counts()

# %%
class_phone_service
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
plt.pie(
    class_phone_service,
    labels=["NO","Yes"],
    autopct="%1.1f%%",
    colors=['b','y'],
    wedgeprops={
        'linewidth': 2,
        'edgecolor': "black"
    }
)
plt.title("Number of phone_service")
plt.tight_layout()

# %%
class_Contract=df["Contract"].value_counts()

# %%
class_Contract
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
plt.pie(
    class_Contract,
    labels=["Month-to-month","Two year","One year"],
    autopct="%1.1f%%",
    colors=['y','r','g'],
    wedgeprops={
        'linewidth': 2,
        'edgecolor': "black"
    }
)
plt.title("Number of phone_service")
plt.tight_layout()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 15))
sns.countplot(ax=axes[0,0], data=df, x='Contract', hue="Churn")
sns.countplot(ax=axes[0,1], data=df, x='MultipleLines', hue="Churn")
sns.countplot(ax=axes[1,0], data=df, x='PaymentMethod', hue="Churn")
sns.countplot(ax=axes[1,1], data=df, x='Dependents', hue="Churn")
plt.tight_layout()
